# %%
import pandas as pd
import numpy as np

music = pd.read_csv('trial.csv')

# %%
music
# Out:
#    acousticness                                            artists  \
# 0       0.07130                                         ['K-Rino']
# 1       0.07010  ['Seven Lions', 'ILLENIUM', 'Said the Sky', 'H...
# 2       0.00001         ['ILLENIUM', 'Joni Fatora', 'Seven Lions']
# 3       0.22000                    ['Gryffin', 'ILLENIUM', 'Daya']
# 4       0.99100                                    ['Mamie Smith']
# 5       0.64300                          ["Screamin' Jay Hawkins"]
# 6       0.00460                                    ['Linkin Park']
# 7       0.06860                                    ['Linkin Park']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.833       221640   0.627         1  79HAjx6ZXIRNOCvxq6Uvlh
# 1         0.441       259556   0.753         0  6BDLcvvtyJD2vnXRDi1IjQ
# 2         0.475        79947   0.929         0  3amCL62ccNSbpdAQHMIaqd
# 3         0.625       248156   0.707         0  0Ev562zA4pmUsBqjxsxxdx
# ...

# %%
music_feat = music.drop(['artists', 'duration_ms', 'id', 'mode', 'name', 'release_date'], axis=1)
music_feat
# Out:
#    acousticness  danceability  energy  explicit  instrumentalness  key  \
# 0       0.07130         0.833   0.627         1          0.000000    6
# 1       0.07010         0.441   0.753         0          0.000000    0
# 2       0.00001         0.475   0.929         0          0.724000    7
# 3       0.22000         0.625   0.707         0          0.000000    2
# 4       0.99100         0.598   0.224         0          0.000522    5
# 5       0.64300         0.852   0.517         0          0.026400    5
# 6       0.00460         0.496   0.863         0          0.000000    9
# 7       0.06860         0.615   0.911         0          0.001880    1
#
#    liveness  loudness  popularity  speechiness    tempo  valence  year
# 0    0.1090    -6.768           1       0.2750   79.953    0.457  2003
# 1    0.0270    -4.074          59       0.0440  135.015    0.254  2016
# 2    0.5640    -7.616           5       0.0551  133.995    0.369  2016
# ...

# %%
song = music['name']
song
# Out:
# 0                                       You Ain't Real
# 1                                         Rush Over Me
# 2    Fortress (feat. Joni Fatora) [Mix Cut] - Seven...
# 3                               Feel Good (feat. Daya)
# 4                             Keep A Song In Your Soul
# 5                                 I Put A Spell On You
# 6                                                 Numb
# 7                                      CASTLE OF GLASS
# Name: name, dtype: object

# %%
trial = pd.concat([song, music_feat], axis=1)
test = trial.iloc[3,:]
trial.drop(3, inplace=True)

# %%
test
# Out:
# name                Feel Good (feat. Daya)
# acousticness                          0.22
# danceability                         0.625
# energy                               0.707
# explicit                                 0
# instrumentalness                         0
# key                                      2
# liveness                             0.213
# loudness                            -4.761
# popularity                              70
# speechiness                         0.0337
# tempo                              138.064
# valence                              0.479
# year                                  2017
# Name: 3, dtype: object

# %%
trial.set_index('name', inplace=True)

# %%
trial
# Out:
#                                                     acousticness  \
# name
# You Ain't Real                                           0.07130
# Rush Over Me                                             0.07010
# Fortress (feat. Joni Fatora) [Mix Cut] - Seven ...       0.00001
# Keep A Song In Your Soul                                 0.99100
# I Put A Spell On You                                     0.64300
# Numb                                                     0.00460
# CASTLE OF GLASS                                          0.06860
#
#                                                     danceability  energy  \
# name
# You Ain't Real                                             0.833   0.627
# Rush Over Me                                               0.441   0.753
# Fortress (feat. Joni Fatora) [Mix Cut] - Seven ...         0.475   0.929
# Keep A Song In Your Soul                                   0.598   0.224
# ...

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(trial)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
test.rename(test[0], inplace=True)
test.drop(labels='name')
test
# Out:
# name                Feel Good (feat. Daya)
# acousticness                          0.22
# danceability                         0.625
# energy                               0.707
# explicit                                 0
# instrumentalness                         0
# key                                      2
# liveness                             0.213
# loudness                            -4.761
# popularity                              70
# speechiness                         0.0337
# tempo                              138.064
# valence                              0.479
# year                                  2017
# Name: Feel Good (feat. Daya), dtype: object

# %%
test.drop(labels='name', inplace=True)
test
# Out:
# C:\Users\Victor\anaconda3\lib\site-packages\pandas\core\generic.py:3939: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(obj)
# acousticness           0.22
# danceability          0.625
# energy                0.707
# explicit                  0
# instrumentalness          0
# key                       2
# liveness              0.213
# loudness             -4.761
# popularity               70
# speechiness          0.0337
# tempo               138.064
# valence               0.479
# year                   2017
# Name: Feel Good (feat. Daya), dtype: object

# %%
trial.iloc[1,:]
# Out:
# acousticness           0.0701
# danceability           0.4410
# energy                 0.7530
# explicit               0.0000
# instrumentalness       0.0000
# key                    0.0000
# liveness               0.0270
# loudness              -4.0740
# popularity            59.0000
# speechiness            0.0440
# tempo                135.0150
# valence                0.2540
# year                2016.0000
# Name: Rush Over Me, dtype: float64

# %%
distances, indices = model_knn.kneighbors(test.values.reshape(1, -1), n_neighbors = 1)

# %%
trial.index[indices.flatten()[0]]
# Out:
# 'Rush Over Me'
